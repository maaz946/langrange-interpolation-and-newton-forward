# %% [markdown]
# # NC PROJECT

# %%
from tkinter import*

cal=Tk()
cal.title("Calculator")
operator=""
text_Input=StringVar()
text_Input2=StringVar()
ment1=StringVar()
ment2=StringVar()
ment3=StringVar()
ment4=StringVar()
n=0
i=0
j=0
x=[]
y=[[]]

def btnStore():
    global i
    print(x)
    x[i]=(float(ment2.get()))
    ment2.set("")
    print(x)
    print(i)
    i=i+1
    b2=Button(cal,padx=8,pady=6,fg='yellow',font=('Ubuntu',14,'bold'),text="Store x"+str(i),command=btnStore,bg='brown').grid(row=11,column=3)

def btnStoren():
    global n
    global x
    global y
    n=int(ment1.get())
    x=[0]*n
    y = [[0 for i in range(n)] for j in range(n)]
    print(x)
    print(y)
    l3=Label(cal,text="Enter "+str(n)+" x values").grid(row=11,column=1)
    l4=Label(cal,text="Enter "+str(n)+" y values").grid(row=12,column=1)

def btnStore1():
    global j
    print(y)
    y[j][0]=(float(ment3.get()))
    ment3.set("")
    print(y)
    print(j)
    j=j+1
    b3=Button(cal,padx=8,pady=6,fg='yellow',font=('Ubuntu',14,'bold'),text="Store y"+str(j),command=btnStore1,bg='brown').grid(row=12,column=3)

def btnStore2():
    value=float(ment4.get())
    for i in range(1,n):
        for j in range(n-i):
            y[j][i]=y[j+1][i-1]-y[j][i-1]
    sum = y[0][0]
    u = (value-x[0])/(x[1]-x[0])
    for i in range(1,n):
        sum=sum+(u_cal(u,i)*y[0][i])/fact(i)
    text_Input2.set(str(round(sum,6)))

def u_cal(u, n):
    temp = u
    for i in range(1, n):
        temp = temp * (u - i)
    return temp

def fact(n):
    f = 1
    for i in range(2, n + 1):
        f *= i
    return f
   

txtDisplay=Entry(cal,font=('Ubuntu',20,'bold'),textvariable=text_Input,bd=5,insertwidth=20,bg='brown',justify='right').grid(columnspan=10)

btn7=Button(cal,padx=8,bd=2,fg='yellow',font=('Ubuntu',20,'bold'),text="7",command=lambda:btnClick(7),bg='brown').grid(row=1,column=0)
btn8=Button(cal,padx=8,bd=2,fg='yellow',font=('Ubuntu',20,'bold'),text="8",command=lambda:btnClick(8),bg='brown').grid(row=1,column=1)
btn9=Button(cal,padx=8,bd=2,fg='yellow',font=('Ubuntu',20,'bold'),text="9",command=lambda:btnClick(9),bg='brown').grid(row=1,column=2)
Addition=Button(cal,padx=8,bd=2,fg="yellow",font=('Ubuntu',20,'bold'),text="+",command=lambda:btnClick("+"),bg='brown').grid(row=1,column=3)

# %%
from tkinter import*
cal=Tk()
text_Input2=StringVar()
ment1=StringVar()
ment2=StringVar()
ment3=StringVar()
ment4=StringVar()
ment5=StringVar()
n=0
i=0
j=0
x=[]
y=[]
def btnStore():
    global i
    print(x)
    x[i]=(float(ment2.get()))
    ment2.set("")
    print(x)
    if i!=n-1:
        i=i+1
    b2=Button(cal,padx=8,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Store x"+str(i),command=btnStore,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=12,column=3,pady=5)
def btnStoren():
    global x
    global y
    n=int(ment1.get())
    l3=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter "+str(n)+" x values").grid(row=12,column=1)
    l4=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter "+str(n)+" y values").grid(row=13,column=1)
def btnStoren():
    value1=int(ment5.get())
    global n
    global x
    global y
    n=int(ment1.get())
    if value1==1.0: 
        y=[]
        x=[0 for i in range(n)]
        y = [0 for i in range(n)]
        print(x)
        print(y)
        l3=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter "+str(n)+" x values").grid(row=12,column=1)
        l4=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter "+str(n)+" y values").grid(row=13,column=1)
    
    else:
        y=[[]]
        x=[0]*n
        y = [[0 for i in range(n)] for j in range(n)]
        print(x)
        print(y)
        l3=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter "+str(n)+" x values").grid(row=12,column=1)
        l4=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter "+str(n)+" y values").grid(row=13,column=1)

def btnStore1():
    value1=int(ment5.get())
    global j
    if value1==1.0:
        print(y)
        y[j]=(float(ment3.get()))
        ment3.set("")
        print(y)
        if j!=n-1:
            j=j+1
        b3=Button(cal,padx=8,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Store y"+str(j),command=btnStore1,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=13,column=3)
    else:
        print(y)
        y[j][0]=(float(ment3.get()))
        ment3.set("")
        print(y)
        print(j)
        if j!=n-1:
            j=j+1
        b3=Button(cal,padx=8,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Store y"+str(j),command=btnStore1,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=13,column=3)
    
def btnStore2():
    #Lagrange interpolation 
    
    value1=int(ment5.get())
    if value1==1.0:
        value=float(ment4.get())
        yp=0
        for i in range(n):
            p = 1
            for j in range(n):
                if i != j:
                    p = p * (value - x[j])/(x[i] - x[j])
            yp = yp + p * y[i]   
        text_Input2.set(str(round(yp,6)))
    else:
        value=float(ment4.get())
        for i in range(1,n):
            for j in range(n-i):
                y[j][i]=y[j+1][i-1]-y[j][i-1]
        sum = y[0][0]
        u = (value-x[0])/(x[1]-x[0])
        for i in range(1,n):
            sum=sum+(u_cal(u,i)*y[0][i])/fact(i)
        text_Input2.set(str(round(sum,6)))
def u_cal(u, n):
    temp = u
    for i in range(1, n):
        temp = temp * (u - i)
    return temp

def fact(n):
    f = 1
    for i in range(2, n + 1):
        f *= i
    return f

def btnStore4():
    import sympy as s
    x1=s.Symbol('x')
    yp=0
    value1=int(ment5.get())
    if value1==1.0:        
        yp=0
        for i in range(n):
            p = 1
            for j in range(n):
                if i != j:
                    p = p * (x1 - x[j])/(x[i] - x[j])
            yp = yp + p * y[i]   
        print(yp)
        text_Input2.set(yp)
    else:
        
        for i in range(1,n):
            for j in range(n-i):
                y[j][i]=y[j+1][i-1]-y[j][i-1]
        sum = y[0][0]
        u = (x1-x[0])/(x[1]-x[0])
        for i in range(1,n):
            sum=sum+(u_cal(u,i)*y[0][i])/fact(i)
        print(sum)
        text_Input2.set(sum)

l1=Label(cal,fg='#27ae60',bg="white",text="APPLICATION OF LAGRANGE INTERPOLATION \n AND NEWTON FORWARD FORMULAS",font=('Ubuntu',20,'bold')).grid(row=7,columnspan=4)
txtDisplay2=Entry(cal,fg='white',font=('Ubuntu',20,'bold'),textvariable=text_Input2,bd=5,insertwidth=10,bg='#2ecc71',justify='center').grid(row=15,columnspan=4,pady=10)

l31=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter 1 for langrange & 2 for forward").grid(row=10,column=1)
e21=Entry(cal,bd=10,textvariable=ment5, relief='flat',bg="#F8EFBA").grid(row=10,column=2)
b21=Button(cal,padx=9,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Confirm",command=btnStoren,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=10,column=3,pady=5)

l2=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="No. of X,Y values to enter ?").grid(row=11,column=1)
e1=Entry(cal,bd=10,textvariable=ment1, relief='flat',bg="#F8EFBA").grid(row=11,column=2)
b1=Button(cal,padx=8,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Store   n",command=btnStoren,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=11,column=3)

l3=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter X values").grid(row=12,column=1)
e2=Entry(cal,bd=10,textvariable=ment2, relief='flat',bg="#F8EFBA").grid(row=12,column=2)
b2=Button(cal,padx=8,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Store x"+str(0),command=btnStore,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=12,column=3,pady=5)


l4=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter Y values").grid(row=13,column=1)
e3=Entry(cal,bd=10,textvariable=ment3, relief='flat',bg="#F8EFBA").grid(row=13,column=2)
b3=Button(cal,padx=8,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Store y"+str(0),command=btnStore1,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=13,column=3)

l5=Label(cal,bg="white",fg='#27ae60',font=('Ubuntu',10,'bold'),text="Enter value of X for which value is to be found").grid(row=14,column=1)
e4=Entry(cal,bd=10,textvariable=ment4, relief='flat',bg="#F8EFBA").grid(row=14,column=2)
b4=Button(cal,padx=9,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Confirm",command=btnStore2,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=14,column=3,pady=5)

b5=Button(cal,padx=0,pady=6,fg='white',font=('Ubuntu',14,'bold'),text="Get equation",command=btnStore4,bg='#2ecc71', relief='flat',cursor="hand2").grid(row=15,column=3,pady=5)
cal.configure(bg='#fff')
cal.mainloop()

# %%
def u_cal(u, n):
    temp = u
    for i in range(1, n):
        temp = temp * (u - i)
    return temp
u_cal(5,4)
# Out:
# 120
